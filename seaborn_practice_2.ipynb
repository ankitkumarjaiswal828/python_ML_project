# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\Ankit\\Desktop\\udemy ML coures\\kaggle datasets\\seaborn-data-master\\tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # bar plot

# %%
sns.barplot(df.day , df.total_bill)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(df.total_bill, df.tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x ='total_bill', y ='tip' , hue ='sex',data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x = 'size',y = 'total_bill',hue = 'sex', data =df,orient = 'h',color = 'g' )
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(df.day , df.total_bill, palette='hot', saturation=0.75,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(df.day , df.total_bill, palette='Accent', saturation=0.75,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(df.day , df.total_bill, palette='cool_r', saturation=0.75,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # scatter plot graph

# %%
plt.figure(figsize =(15,5))
sns.scatterplot(x = 'tip',y  = 'total_bill',data = df)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
plt.figure(figsize =(15,5))
sns.scatterplot(x = 'tip',y  = 'total_bill',data = df ,hue ='sex')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
plt.figure(figsize =(15,5))
sns.scatterplot(x = 'tip',y  = 'total_bill',data = df ,hue ='sex',style ='sex'  ,size ='sex',sizes =(100,400))# style ='who'  ,size ='who'
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # heatmap graph

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='hot',linecolor ='k') # annot is stands for the annotation
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='cool') # annot is stands for the annotation
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='cool_r') # annot is stands for the annotation
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='Accent') # annot is stands for the annotation
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='Accent_r') # annot is stands for the annotation
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='coolwarm',linecolor = 'k') # annot is stands for the annotation
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(15,5))
sns.heatmap(df.corr(),annot =True ,linewidths =2 ,cmap ='Accent_r',cbar =False)# cbar is hide color vision
# Out:
# <AxesSubplot:>

# %% [markdown]
# # boxplot() graph

# %%
plt.figure(figsize =(15,5))
sns.boxplot(x = 'tip',y  = 'total_bill',data = df ,hue ='sex')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
plt.figure(figsize =(15,5))
sns.boxplot(x = 'size',y  = 'total_bill',data = df ,hue ='sex')
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
plt.figure(figsize =(15,5))
sns.boxplot(x = 'tip',y  = 'size',data = df ,hue ='sex')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='size'>

# %%
plt.figure(figsize =(15,5))
sns.boxplot(x = 'day',y  = 'smoker',data = df ,hue ='sex') #day and smoker is string values so not excuate,used numeric datasets
